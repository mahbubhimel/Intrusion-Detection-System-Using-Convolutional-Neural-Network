# %% [markdown]
# # **Mount Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Import Necessary Libraries**

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import (StandardScaler, OrdinalEncoder,LabelEncoder, MinMaxScaler, OneHotEncoder)
# !pip install -q keras
from keras.utils import to_categorical
from sklearn.preprocessing import Normalizer, MaxAbsScaler , RobustScaler, PowerTransformer
import matplotlib.pyplot as plt
import seaborn as sns
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, SimpleRNN , GRU , Activation
# from keras.layers.normalization import BatchNormalization
from keras import optimizers
import tensorflow as tf
from tensorflow.keras import layers
from keras.layers import Convolution1D, Dense, Dropout, Flatten, MaxPooling1D , AveragePooling1D
from tensorflow.keras.layers import Input, Dense, Conv1D, MaxPooling1D, Flatten, Dropout, Reshape, LayerNormalization, MultiHeadAttention,Concatenate
import keras
from keras import backend as K
from keras.models import Model
from keras.layers import Input, Conv1D, GlobalMaxPooling1D, Activation, Dense, Dropout, Lambda
from keras.utils import to_categorical

from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import load_model
# !pip install -q pycm
import pycm
from pycm import *
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.metrics import (precision_score, recall_score,
                             f1_score, accuracy_score,mean_squared_error,mean_absolute_error)

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.1/66.1 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 597.6/597.6 kB 48.7 MB/s eta 0:00:00

# %% [markdown]
# # **Import Dataset From Drive**

# %%
train='/content/drive/My Drive/Datasets/NSL-KDD/nsl-kdd/KDDTrain+.txt'
test='/content/drive/My Drive/Datasets/NSL-KDD/nsl-kdd/KDDTest+.txt'
test21='/content/drive/My Drive/Datasets/NSL-KDD/nsl-kdd/KDDTest-21.txt'

# %% [markdown]
# # **Preparing Dataset**

# %%
featureV=["duration","protocol_type","service","flag","src_bytes","dst_bytes","land","wrong_fragment","urgent","hot",
          "num_failed_logins","logged_in","num_compromised","root_shell","su_attempted","num_root","num_file_creations","num_shells",
          "num_access_files","num_outbound_cmds","is_host_login","is_guest_login","count","srv_count","serror_rate","srv_serror_rate",
          "rerror_rate","srv_rerror_rate","same_srv_rate","diff_srv_rate","srv_diff_host_rate","dst_host_count","dst_host_srv_count", 
          "dst_host_same_srv_rate","dst_host_diff_srv_rate","dst_host_same_src_port_rate","dst_host_srv_diff_host_rate","dst_host_serror_rate",
          "dst_host_srv_serror_rate","dst_host_rerror_rate","dst_host_srv_rerror_rate","label","difficulty"]

binary_attack=['normal','ipsweep', 'nmap', 'portsweep','satan', 'saint', 'mscan','back', 'land', 'neptune', 'pod', 'smurf',
               'teardrop', 'apache2', 'udpstorm', 'processtable','mailbomb','buffer_overflow', 'loadmodule', 'perl', 'rootkit',
               'xterm', 'ps', 'sqlattack','ftp_write', 'guess_passwd', 'imap', 'multihop','phf', 'spy', 'warezclient',
               'warezmaster','snmpgetattack','named', 'xlock', 'xsnoop','sendmail', 'httptunnel', 'worm', 'snmpguess']

multiclass_attack={ 'normal': 'normal',
        'probe': ['ipsweep.', 'nmap.', 'portsweep.','satan.', 'saint.', 'mscan.'],
        'dos': ['back.', 'land.', 'neptune.', 'pod.', 'smurf.','teardrop.', 'apache2.', 'udpstorm.', 'processtable.','mailbomb.'],
        'u2r': ['buffer_overflow.', 'loadmodule.', 'perl.', 'rootkit.','xterm.', 'ps.', 'sqlattack.'],
        'r2l': ['ftp_write.', 'guess_passwd.', 'imap.', 'multihop.','phf.', 'spy.', 'warezclient.', 'warezmaster.','snmpgetattack.',
                   'named.', 'xlock.', 'xsnoop.','sendmail.', 'httptunnel.', 'worm.', 'snmpguess.']}

# %%
train_data=pd.read_csv(train,names=featureV)
test_data=pd.read_csv(test,names=featureV)
test_21 = pd.read_csv(test21, names= featureV)

# %% [markdown]
# # **Heatmap**

# %%
heatmap = pd.read_csv(train,names=featureV)
cat_cols = ["protocol_type", "service", "flag"]
le = LabelEncoder()
for col in cat_cols:
    heatmap[col] = le.fit_transform(heatmap[col])

train_data_heatmap = heatmap[['duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes']]

plt.figure(figsize=(12,10))
p=sns.heatmap(train_data_heatmap.corr(), annot=True,cmap ='RdYlGn')
plt.savefig('heatmap.png')

# %% [markdown]
# # **Data Preprocessing**

# %%
train_data = train_data.drop_duplicates()
train_data = train_data.dropna()

test_data = test_data.drop_duplicates()
test_data = test_data.dropna()

test_21 = test_21.drop_duplicates()
test_21 = test_21.dropna()

# %% [markdown]
# # **Hybrid Feature Selection**

# %%
train_data = train_data[['duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes', 'label']]

# One-hot encode the categorical data
train_data = pd.get_dummies(train_data, columns=['protocol_type', 'service', 'flag'])

test_data = test_data[['duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes', 'label']]

# One-hot encode the categorical data
test_data = pd.get_dummies(test_data, columns=['protocol_type', 'service', 'flag'])

test_21 = test_21[['duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes', 'label']]

# One-hot encode the categorical data
test_21 = pd.get_dummies(test_21, columns=['protocol_type', 'service', 'flag'])

# %%
test_data['dummy1'] = 0
test_data['dummy2'] = 0
test_data['dummy3'] = 0
test_data['dummy4'] = 0
test_data['dummy5'] = 0
test_data['dummy6'] = 0

# <<-------------------------------------------------------------------------------->>

test_21['dummy1'] = 0
test_21['dummy2'] = 0
test_21['dummy3'] = 0
test_21['dummy4'] = 0
test_21['dummy5'] = 0
test_21['dummy6'] = 0
test_21['dummy7'] = 0
test_21['dummy8'] = 0

# %%
print(np.shape(train_data))
print(np.shape(test_data))
print(np.shape(test_21))
# Out:
# (125973, 88)
# (22544, 88)
# (11850, 88)

# %%
def preprocessing(data,cls,df):
  
#----------attack categorization----------------->
  data['label']=data['label'].replace(['normal.','normal'],0)

#----------------------binary classification--------------------->
  if cls=='binary':
    for i in range(len(binary_attack)):
      data['label'] = data['label'].replace(binary_attack[i], 1)
  
#---------------multiclass classification-------------------->  
  elif cls=='multiclass':
    for i in range(len(multiclass_attack['probe'])):
      data['label']=data['label'].replace([multiclass_attack['probe'][i],multiclass_attack['probe'][i][:-1]],1)
    
    for i in range(len(multiclass_attack['dos'])):
      data['label']=data['label'].replace([multiclass_attack['dos'][i],multiclass_attack['dos'][i][:-1]],2)
    
    for i in range(len(multiclass_attack['u2r'])):
      data['label']=data['label'].replace([multiclass_attack['u2r'][i],multiclass_attack['u2r'][i][:-1]],3)
    
    for i in range(len(multiclass_attack['r2l'])):
      data['label'] = data['label'].replace([multiclass_attack['r2l'][i],multiclass_attack['r2l'][i][:-1]],4)
#------------------------------------------------>


#-------------------------splitting features and labels---------------->
  y=data['label']
  x=data.iloc[:, :-1]

#-----------------converting to binary label vectors--------------------------------------> 
  yt=y.copy()
  yt=pd.get_dummies(yt)
#------------------------------------------------------------------------------>

  x = MinMaxScaler(feature_range=(0, 1)).fit_transform(x)
    
  return x,yt

# %%
x_train,Y_train=preprocessing(train_data,cls='multiclass',df='train')
x_test,Y_test=preprocessing(test_data,cls='multiclass',df='test')
x_21_test, y_21_test = preprocessing(test_21, cls = 'multiclass', df = 'test21')

# %%
print(np.shape(x_train))
print(np.shape(Y_train))
print(np.shape(x_test))
print(np.shape(Y_test))
print(np.shape(x_21_test))
print(np.shape(y_21_test))
# Out:
# (125973, 87)
# (125973, 5)
# (22544, 87)
# (22544, 5)
# (11850, 87)
# (11850, 5)

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_train.shape
# Out:
# (125973, 87, 1)

# %%
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
x_test.shape
# Out:
# (22544, 87, 1)

# %%
x_21_test = np.reshape(x_21_test, (x_21_test.shape[0], x_21_test.shape[1], 1))
x_21_test.shape
# Out:
# (11850, 87, 1)

# %% [markdown]
# # **Model**

# %%
inputs = Input(shape=(x_train.shape[1], 1))
x = Convolution1D(512, 3, padding="same",activation="relu")(inputs)
x = tf.keras.layers.LayerNormalization()(x)
# model.add(Convolution1D(32, 3, activation="relu"))
x = MaxPooling1D(pool_size=(2))(x)
# model.add(tf.keras.layers.LayerNormalization())
# model.add(GRU(units = 128, return_sequences=True, input_shape = (x_train.shape[1], 1)))
x = Dropout(0.5)(x) 
x = Convolution1D(128, 3, padding="same",activation="relu")(x)
x = MaxPooling1D(pool_size=(2))(x)
x = Dropout(0.5)(x) 

x = Convolution1D(64, 4, padding="same",activation="relu")(x)
x = MaxPooling1D(pool_size=(2))(x)
x = Dropout(0.5)(x)
print(x.shape)
    
# Flatten the output of multihead attention layer
flattened_attention = Flatten()(x)

d2 = Dense(128, activation="relu")(flattened_attention)
d3 = Dropout(0.5)(d2)
output = Dense(5, activation="softmax")(d3)
# Out:
# (None, 10, 64)

# %%
model = keras.Model(inputs=inputs, outputs=output)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 87, 1)]           0
#
#  conv1d (Conv1D)             (None, 87, 512)           2048
#
#  layer_normalization (LayerN  (None, 87, 512)          1024
#  ormalization)
#
#  max_pooling1d (MaxPooling1D  (None, 43, 512)          0
#  )
#
#  dropout (Dropout)           (None, 43, 512)           0
#
#  conv1d_1 (Conv1D)           (None, 43, 128)           196736
#
#  max_pooling1d_1 (MaxPooling  (None, 21, 128)          0
#  1D)
#
#  dropout_1 (Dropout)         (None, 21, 128)           0
#
#  conv1d_2 (Conv1D)           (None, 21, 64)            32832
#
#  max_pooling1d_2 (MaxPooling  (None, 10, 64)           0
#  1D)
#
#  dropout_2 (Dropout)         (None, 10, 64)            0
#
#  flatten (Flatten)           (None, 640)               0
#
#  dense (Dense)               (None, 128)               82048
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 315,333
# Trainable params: 315,333
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.vis_utils.plot_model(model,to_file='multiclass_model.png',show_shapes=True, show_layer_names=True, show_layer_activations = True)

# %%
optimizer = tf.keras.optimizers.experimental.RMSprop(
    learning_rate=0.001,
    rho=0.9,
    momentum=0.0,
    epsilon=1e-08,
    centered=False,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=100,
    jit_compile=True
)
# train_op = tf.keras.optimizers.adam(amsgrad=True)
model.compile(optimizer = optimizer ,loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import CSVLogger

filepath = '/content/drive/My Drive/Datasets/NSL-KDD/multi_small_model_without_att_one_hot_rms_min_lr_0.001.hdf5'
checkpoint = ModelCheckpoint(filepath, 
                             monitor='val_accuracy', 
                             verbose=1, 
                             save_best_only=True,
                             mode='max')

reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', mode='max',factor=0.2, patience=5, min_lr=0.001, cooldown = 1, focus='val_accuracy')
# reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', mode='max',factor=0.2, patience=5, min_lr=0.001)

csv_logger = CSVLogger('training.log')

callbacks_list = [checkpoint, reduce_lr, csv_logger]

# %%
history = model.fit(x_train, Y_train, epochs = 150, validation_data=(x_test, Y_test),batch_size = 512, callbacks= callbacks_list)
# Out:
# Epoch 1/150
# 247/247 [==============================] - ETA: 0s - loss: 0.1190 - accuracy: 0.9592
# Epoch 1: val_accuracy improved from -inf to 0.82066, saving model to /content/drive/My Drive/Datasets/NSL-KDD/multi_small_model_without_att_one_hot_rms_min_lr_0.001.hdf5
# 247/247 [==============================] - 28s 51ms/step - loss: 0.1190 - accuracy: 0.9592 - val_loss: 0.9251 - val_accuracy: 0.8207 - lr: 0.0010
# Epoch 2/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0142 - accuracy: 0.9961
# Epoch 2: val_accuracy improved from 0.82066 to 0.89403, saving model to /content/drive/My Drive/Datasets/NSL-KDD/multi_small_model_without_att_one_hot_rms_min_lr_0.001.hdf5
# 247/247 [==============================] - 10s 41ms/step - loss: 0.0142 - accuracy: 0.9961 - val_loss: 0.4353 - val_accuracy: 0.8940 - lr: 0.0010
# Epoch 3/150
# 247/247 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9979
# Epoch 3: val_accuracy improved from 0.89403 to 0.92082, saving model to /content/drive/My Drive/Datasets/NSL-KDD/multi_small_model_without_att_one_hot_rms_min_lr_0.001.hdf5
# 247/247 [==============================] - 11s 45ms/step - loss: 0.0081 - accuracy: 0.9979 - val_loss: 0.3304 - val_accuracy: 0.9208 - lr: 0.0010
# Epoch 4/150
# 247/247 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9984
# Epoch 4: val_accuracy improved from 0.92082 to 0.93750, saving model to /content/drive/My Drive/Datasets/NSL-KDD/multi_small_model_without_att_one_hot_rms_min_lr_0.001.hdf5
# 247/247 [==============================] - 12s 47ms/step - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.3464 - val_accuracy: 0.9375 - lr: 0.0010
# Epoch 5/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0051 - accuracy: 0.9988
# Epoch 5: val_accuracy improved from 0.93750 to 0.97294, saving model to /content/drive/My Drive/Datasets/NSL-KDD/multi_small_model_without_att_one_hot_rms_min_lr_0.001.hdf5
# 247/247 [==============================] - 11s 46ms/step - loss: 0.0051 - accuracy: 0.9988 - val_loss: 0.4539 - val_accuracy: 0.9729 - lr: 0.0010
# Epoch 6/150
# 247/247 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9989
# Epoch 6: val_accuracy did not improve from 0.97294
# 247/247 [==============================] - 11s 44ms/step - loss: 0.0043 - accuracy: 0.9989 - val_loss: 0.2457 - val_accuracy: 0.9718 - lr: 0.0010
# Epoch 7/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0045 - accuracy: 0.9990
# Epoch 7: val_accuracy improved from 0.97294 to 0.97418, saving model to /content/drive/My Drive/Datasets/NSL-KDD/multi_small_model_without_att_one_hot_rms_min_lr_0.001.hdf5
# 247/247 [==============================] - 12s 49ms/step - loss: 0.0045 - accuracy: 0.9990 - val_loss: 0.0948 - val_accuracy: 0.9742 - lr: 0.0010
# Epoch 8/150
# 246/247 [============================>.] - ETA: 0s - loss: 0.0036 - accuracy: 0.9993
# Epoch 8: val_accuracy did not improve from 0.97418
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0036 - accuracy: 0.9993 - val_loss: 0.1970 - val_accuracy: 0.9739 - lr: 0.0010
# Epoch 9/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0040 - accuracy: 0.9991
# Epoch 9: val_accuracy did not improve from 0.97418
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0040 - accuracy: 0.9991 - val_loss: 0.1062 - val_accuracy: 0.9740 - lr: 0.0010
# Epoch 10/150
# 246/247 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.9992
# Epoch 10: val_accuracy did not improve from 0.97418
# 247/247 [==============================] - 11s 46ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.2022 - val_accuracy: 0.9738 - lr: 0.0010
# Epoch 11/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0036 - accuracy: 0.9992
# Epoch 11: val_accuracy did not improve from 0.97418
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 0.2527 - val_accuracy: 0.9734 - lr: 0.0010
# Epoch 12/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0030 - accuracy: 0.9993
# Epoch 12: val_accuracy improved from 0.97418 to 0.97436, saving model to /content/drive/My Drive/Datasets/NSL-KDD/multi_small_model_without_att_one_hot_rms_min_lr_0.001.hdf5
# 247/247 [==============================] - 11s 46ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.1733 - val_accuracy: 0.9744 - lr: 0.0010
# Epoch 13/150
# 246/247 [============================>.] - ETA: 0s - loss: 0.0031 - accuracy: 0.9993
# Epoch 13: val_accuracy improved from 0.97436 to 0.99676, saving model to /content/drive/My Drive/Datasets/NSL-KDD/multi_small_model_without_att_one_hot_rms_min_lr_0.001.hdf5
# 247/247 [==============================] - 12s 47ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 0.0196 - val_accuracy: 0.9968 - lr: 0.0010
# Epoch 14/150
# 246/247 [============================>.] - ETA: 0s - loss: 0.0035 - accuracy: 0.9992
# Epoch 14: val_accuracy did not improve from 0.99676
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.0924 - val_accuracy: 0.9742 - lr: 0.0010
# Epoch 15/150
# 247/247 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9994
# Epoch 15: val_accuracy did not improve from 0.99676
# 247/247 [==============================] - 11s 45ms/step - loss: 0.0033 - accuracy: 0.9994 - val_loss: 0.0288 - val_accuracy: 0.9964 - lr: 0.0010
# Epoch 16/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0030 - accuracy: 0.9993
# Epoch 16: val_accuracy did not improve from 0.99676
# 247/247 [==============================] - 11s 45ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 0.0283 - val_accuracy: 0.9965 - lr: 0.0010
# Epoch 17/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0026 - accuracy: 0.9994
# Epoch 17: val_accuracy did not improve from 0.99676
# 247/247 [==============================] - 11s 45ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0826 - val_accuracy: 0.9743 - lr: 0.0010
# Epoch 18/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0028 - accuracy: 0.9993
# Epoch 18: val_accuracy did not improve from 0.99676
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0029 - accuracy: 0.9993 - val_loss: 0.0449 - val_accuracy: 0.9964 - lr: 0.0010
# Epoch 19/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0031 - accuracy: 0.9994
# Epoch 19: val_accuracy did not improve from 0.99676
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0030 - accuracy: 0.9995 - val_loss: 0.0342 - val_accuracy: 0.9964 - lr: 0.0010
# Epoch 20/150
# 247/247 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9995
# Epoch 20: val_accuracy did not improve from 0.99676
# 247/247 [==============================] - 11s 46ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.0731 - val_accuracy: 0.9964 - lr: 0.0010
# Epoch 21/150
# 247/247 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9996
# Epoch 21: val_accuracy did not improve from 0.99676
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.0724 - val_accuracy: 0.9968 - lr: 0.0010
# Epoch 22/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0030 - accuracy: 0.9993
# Epoch 22: val_accuracy did not improve from 0.99676
# 247/247 [==============================] - 10s 42ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.0822 - val_accuracy: 0.9965 - lr: 0.0010
# Epoch 23/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9996
# Epoch 23: val_accuracy did not improve from 0.99676
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.0792 - val_accuracy: 0.9965 - lr: 0.0010
# Epoch 24/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.9994
# Epoch 24: val_accuracy did not improve from 0.99676
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0034 - accuracy: 0.9994 - val_loss: 0.0756 - val_accuracy: 0.9965 - lr: 0.0010
# Epoch 25/150
# 247/247 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9994
# Epoch 25: val_accuracy improved from 0.99676 to 0.99681, saving model to /content/drive/My Drive/Datasets/NSL-KDD/multi_small_model_without_att_one_hot_rms_min_lr_0.001.hdf5
# 247/247 [==============================] - 12s 48ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0293 - val_accuracy: 0.9968 - lr: 0.0010
# Epoch 26/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0022 - accuracy: 0.9995
# Epoch 26: val_accuracy did not improve from 0.99681
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.0294 - val_accuracy: 0.9968 - lr: 0.0010
# Epoch 27/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0032 - accuracy: 0.9995
# Epoch 27: val_accuracy did not improve from 0.99681
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0031 - accuracy: 0.9995 - val_loss: 0.0488 - val_accuracy: 0.9968 - lr: 0.0010
# Epoch 28/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0022 - accuracy: 0.9995
# Epoch 28: val_accuracy did not improve from 0.99681
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.0461 - val_accuracy: 0.9968 - lr: 0.0010
# Epoch 29/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0022 - accuracy: 0.9995
# Epoch 29: val_accuracy did not improve from 0.99681
# 247/247 [==============================] - 11s 44ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.0384 - val_accuracy: 0.9968 - lr: 0.0010
# Epoch 30/150
# 247/247 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9996
# Epoch 30: val_accuracy did not improve from 0.99681
# 247/247 [==============================] - 11s 45ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0585 - val_accuracy: 0.9966 - lr: 0.0010
# Epoch 31/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0031 - accuracy: 0.9995
# Epoch 31: val_accuracy did not improve from 0.99681
# 247/247 [==============================] - 10s 42ms/step - loss: 0.0031 - accuracy: 0.9995 - val_loss: 0.0429 - val_accuracy: 0.9968 - lr: 0.0010
# Epoch 32/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9997
# Epoch 32: val_accuracy did not improve from 0.99681
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.1239 - val_accuracy: 0.9963 - lr: 0.0010
# Epoch 33/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9996
# Epoch 33: val_accuracy did not improve from 0.99681
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.0621 - val_accuracy: 0.9966 - lr: 0.0010
# Epoch 34/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0023 - accuracy: 0.9995
# Epoch 34: val_accuracy did not improve from 0.99681
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.0601 - val_accuracy: 0.9966 - lr: 0.0010
# Epoch 35/150
# 247/247 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9996
# Epoch 35: val_accuracy did not improve from 0.99681
# 247/247 [==============================] - 11s 45ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.0576 - val_accuracy: 0.9966 - lr: 0.0010
# Epoch 36/150
# 247/247 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9996
# Epoch 36: val_accuracy did not improve from 0.99681
# 247/247 [==============================] - 11s 45ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.0567 - val_accuracy: 0.9966 - lr: 0.0010
# Epoch 37/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0029 - accuracy: 0.9995
# Epoch 37: val_accuracy did not improve from 0.99681
# 247/247 [==============================] - 11s 45ms/step - loss: 0.0029 - accuracy: 0.9995 - val_loss: 0.0674 - val_accuracy: 0.9965 - lr: 0.0010
# Epoch 38/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9997
# Epoch 38: val_accuracy did not improve from 0.99681
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0485 - val_accuracy: 0.9966 - lr: 0.0010
# Epoch 39/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9995
# Epoch 39: val_accuracy did not improve from 0.99681
# 247/247 [==============================] - 11s 45ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.0615 - val_accuracy: 0.9966 - lr: 0.0010
# Epoch 40/150
# 246/247 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9996
# Epoch 40: val_accuracy did not improve from 0.99681
# 247/247 [==============================] - 11s 45ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0963 - val_accuracy: 0.9966 - lr: 0.0010
# Epoch 41/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9997
# Epoch 41: val_accuracy did not improve from 0.99681
# 247/247 [==============================] - 11s 45ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0318 - val_accuracy: 0.9966 - lr: 0.0010
# Epoch 42/150
# 247/247 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9994
# Epoch 42: val_accuracy did not improve from 0.99681
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.0504 - val_accuracy: 0.9968 - lr: 0.0010
# Epoch 43/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9996
# Epoch 43: val_accuracy did not improve from 0.99681
# 247/247 [==============================] - 11s 45ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.0993 - val_accuracy: 0.9966 - lr: 0.0010
# Epoch 44/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0029 - accuracy: 0.9996
# Epoch 44: val_accuracy did not improve from 0.99681
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0029 - accuracy: 0.9996 - val_loss: 0.0616 - val_accuracy: 0.9966 - lr: 0.0010
# Epoch 45/150
# 247/247 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9996
# Epoch 45: val_accuracy did not improve from 0.99681
# 247/247 [==============================] - 11s 45ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.0678 - val_accuracy: 0.9965 - lr: 0.0010
# Epoch 46/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9996
# Epoch 46: val_accuracy did not improve from 0.99681
# 247/247 [==============================] - 10s 42ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.1006 - val_accuracy: 0.9966 - lr: 0.0010
# Epoch 47/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0023 - accuracy: 0.9997
# Epoch 47: val_accuracy did not improve from 0.99681
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0024 - accuracy: 0.9997 - val_loss: 0.0745 - val_accuracy: 0.9965 - lr: 0.0010
# Epoch 48/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0023 - accuracy: 0.9996
# Epoch 48: val_accuracy did not improve from 0.99681
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.1029 - val_accuracy: 0.9965 - lr: 0.0010
# Epoch 49/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0022 - accuracy: 0.9996
# Epoch 49: val_accuracy did not improve from 0.99681
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.0598 - val_accuracy: 0.9968 - lr: 0.0010
# Epoch 50/150
# 247/247 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9996
# Epoch 50: val_accuracy did not improve from 0.99681
# 247/247 [==============================] - 11s 45ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.0326 - val_accuracy: 0.9967 - lr: 0.0010
# Epoch 51/150
# 247/247 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9996
# Epoch 51: val_accuracy did not improve from 0.99681
# 247/247 [==============================] - 11s 45ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.0742 - val_accuracy: 0.9966 - lr: 0.0010
# Epoch 52/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.9997
# Epoch 52: val_accuracy improved from 0.99681 to 0.99685, saving model to /content/drive/My Drive/Datasets/NSL-KDD/multi_small_model_without_att_one_hot_rms_min_lr_0.001.hdf5
# 247/247 [==============================] - 12s 48ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0571 - val_accuracy: 0.9969 - lr: 0.0010
# Epoch 53/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9996
# Epoch 53: val_accuracy did not improve from 0.99685
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.1090 - val_accuracy: 0.9966 - lr: 0.0010
# Epoch 54/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0022 - accuracy: 0.9996
# Epoch 54: val_accuracy did not improve from 0.99685
# 247/247 [==============================] - 11s 45ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.0370 - val_accuracy: 0.9968 - lr: 0.0010
# Epoch 55/150
# 247/247 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9996
# Epoch 55: val_accuracy did not improve from 0.99685
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0025 - accuracy: 0.9996 - val_loss: 0.0659 - val_accuracy: 0.9967 - lr: 0.0010
# Epoch 56/150
# 247/247 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9996
# Epoch 56: val_accuracy did not improve from 0.99685
# 247/247 [==============================] - 11s 45ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 0.0791 - val_accuracy: 0.9965 - lr: 0.0010
# Epoch 57/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9997
# Epoch 57: val_accuracy did not improve from 0.99685
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0427 - val_accuracy: 0.9969 - lr: 0.0010
# Epoch 58/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9996
# Epoch 58: val_accuracy did not improve from 0.99685
# 247/247 [==============================] - 11s 46ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.0435 - val_accuracy: 0.9968 - lr: 0.0010
# Epoch 59/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9997
# Epoch 59: val_accuracy did not improve from 0.99685
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0497 - val_accuracy: 0.9968 - lr: 0.0010
# Epoch 60/150
# 247/247 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9996
# Epoch 60: val_accuracy did not improve from 0.99685
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.0548 - val_accuracy: 0.9968 - lr: 0.0010
# Epoch 61/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9997
# Epoch 61: val_accuracy did not improve from 0.99685
# 247/247 [==============================] - 11s 45ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0619 - val_accuracy: 0.9965 - lr: 0.0010
# Epoch 62/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0023 - accuracy: 0.9996
# Epoch 62: val_accuracy did not improve from 0.99685
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.0803 - val_accuracy: 0.9966 - lr: 0.0010
# Epoch 63/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0022 - accuracy: 0.9995
# Epoch 63: val_accuracy did not improve from 0.99685
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.0525 - val_accuracy: 0.9968 - lr: 0.0010
# Epoch 64/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9997
# Epoch 64: val_accuracy did not improve from 0.99685
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0682 - val_accuracy: 0.9966 - lr: 0.0010
# Epoch 65/150
# 247/247 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9997
# Epoch 65: val_accuracy improved from 0.99685 to 0.99689, saving model to /content/drive/My Drive/Datasets/NSL-KDD/multi_small_model_without_att_one_hot_rms_min_lr_0.001.hdf5
# 247/247 [==============================] - 12s 49ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0656 - val_accuracy: 0.9969 - lr: 0.0010
# Epoch 66/150
# 246/247 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch
150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0010 - accuracy: 0.9998
# Epoch 120: val_accuracy improved from 0.99689 to 0.99694, saving model to /content/drive/My Drive/Datasets/NSL-KDD/multi_small_model_without_att_one_hot_rms_min_lr_0.001.hdf5
# 247/247 [==============================] - 11s 45ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0606 - val_accuracy: 0.9969 - lr: 0.0010
# Epoch 121/150
# 247/247 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9998
# Epoch 121: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0693 - val_accuracy: 0.9969 - lr: 0.0010
# Epoch 122/150
# 247/247 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9998
# Epoch 122: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 11s 45ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0559 - val_accuracy: 0.9969 - lr: 0.0010
# Epoch 123/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9998
# Epoch 123: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 11s 45ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0777 - val_accuracy: 0.9968 - lr: 0.0010
# Epoch 124/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9998
# Epoch 124: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 10s 42ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0313 - val_accuracy: 0.9969 - lr: 0.0010
# Epoch 125/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.9997
# Epoch 125: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 10s 43ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0625 - val_accuracy: 0.9968 - lr: 0.0010
# Epoch 126/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9999
# Epoch 126: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 10s 43ms/step - loss: 0.0014 - accuracy: 0.9999 - val_loss: 0.0768 - val_accuracy: 0.9968 - lr: 0.0010
# Epoch 127/150
# 247/247 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9997
# Epoch 127: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 11s 45ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0712 - val_accuracy: 0.9968 - lr: 0.0010
# Epoch 128/150
# 245/247 [============================>.] - ETA: 0s - loss: 8.8121e-04 - accuracy: 0.9998
# Epoch 128: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 11s 45ms/step - loss: 8.7749e-04 - accuracy: 0.9998 - val_loss: 0.0946 - val_accuracy: 0.9968 - lr: 0.0010
# Epoch 129/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9998
# Epoch 129: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 10s 42ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1008 - val_accuracy: 0.9968 - lr: 0.0010
# Epoch 130/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9998
# Epoch 130: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 10s 42ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.0611 - val_accuracy: 0.9969 - lr: 0.0010
# Epoch 131/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9998
# Epoch 131: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.0695 - val_accuracy: 0.9968 - lr: 0.0010
# Epoch 132/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9998
# Epoch 132: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 11s 45ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0587 - val_accuracy: 0.9969 - lr: 0.0010
# Epoch 133/150
# 246/247 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9998
# Epoch 133: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 10s 42ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0834 - val_accuracy: 0.9969 - lr: 0.0010
# Epoch 134/150
# 246/247 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9998
# Epoch 134: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0765 - val_accuracy: 0.9969 - lr: 0.0010
# Epoch 135/150
# 247/247 [==============================] - ETA: 0s - loss: 7.5511e-04 - accuracy: 0.9999
# Epoch 135: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 11s 43ms/step - loss: 7.5511e-04 - accuracy: 0.9999 - val_loss: 0.0972 - val_accuracy: 0.9968 - lr: 0.0010
# Epoch 136/150
# 247/247 [==============================] - ETA: 0s - loss: 7.0110e-04 - accuracy: 0.9999
# Epoch 136: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 11s 43ms/step - loss: 7.0110e-04 - accuracy: 0.9999 - val_loss: 0.0977 - val_accuracy: 0.9969 - lr: 0.0010
# Epoch 137/150
# 247/247 [==============================] - ETA: 0s - loss: 8.2990e-04 - accuracy: 0.9999
# Epoch 137: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 11s 45ms/step - loss: 8.2990e-04 - accuracy: 0.9999 - val_loss: 0.0501 - val_accuracy: 0.9969 - lr: 0.0010
# Epoch 138/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9998
# Epoch 138: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 10s 42ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0506 - val_accuracy: 0.9969 - lr: 0.0010
# Epoch 139/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9998
# Epoch 139: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 11s 45ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0583 - val_accuracy: 0.9969 - lr: 0.0010
# Epoch 140/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0010 - accuracy: 0.9998
# Epoch 140: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0572 - val_accuracy: 0.9969 - lr: 0.0010
# Epoch 141/150
# 247/247 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9998
# Epoch 141: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.0400 - val_accuracy: 0.9969 - lr: 0.0010
# Epoch 142/150
# 247/247 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9998
# Epoch 142: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 10s 42ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0835 - val_accuracy: 0.9968 - lr: 0.0010
# Epoch 143/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9998
# Epoch 143: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0813 - val_accuracy: 0.9969 - lr: 0.0010
# Epoch 144/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9998
# Epoch 144: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0017 - accuracy: 0.9998 - val_loss: 0.0741 - val_accuracy: 0.9969 - lr: 0.0010
# Epoch 145/150
# 247/247 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9998
# Epoch 145: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0017 - accuracy: 0.9998 - val_loss: 0.0726 - val_accuracy: 0.9969 - lr: 0.0010
# Epoch 146/150
# 247/247 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9998
# Epoch 146: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 11s 45ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 0.0834 - val_accuracy: 0.9969 - lr: 0.0010
# Epoch 147/150
# 245/247 [============================>.] - ETA: 0s - loss: 7.5703e-04 - accuracy: 0.9999
# Epoch 147: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 10s 42ms/step - loss: 7.5442e-04 - accuracy: 0.9999 - val_loss: 0.0801 - val_accuracy: 0.9969 - lr: 0.0010
# Epoch 148/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9998
# Epoch 148: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0602 - val_accuracy: 0.9969 - lr: 0.0010
# Epoch 149/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9998
# Epoch 149: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 11s 43ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.0781 - val_accuracy: 0.9969 - lr: 0.0010
# Epoch 150/150
# 245/247 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9997
# Epoch 150: val_accuracy did not improve from 0.99694
# 247/247 [==============================] - 11s 45ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0791 - val_accuracy: 0.9969 - lr: 0.0010

# %%
model = load_model('/content/drive/My Drive/Datasets/NSL-KDD/multi_small_model_without_att_one_hot_rms_min_lr_0.001.hdf5')

# %%
test_loss, test_acc = model.evaluate(x_21_test, y_21_test)

print(test_loss)
print(test_acc)
# Out:
# 371/371 [==============================] - 2s 5ms/step - loss: 0.1391 - accuracy: 0.9941
# 0.13908007740974426
# 0.9940928220748901

# %%
accuracy = history.history['accuracy']
epochs = range(1, len(accuracy) + 1)

# %%
accuracy
# Out:
# [0.9592134952545166,
#  0.9960547089576721,
#  0.997888445854187,
#  0.998428225517273,
#  0.998809278011322,
#  0.9989362955093384,
#  0.9989759922027588,
#  0.9992538094520569,
#  0.9990870952606201,
#  0.9992141127586365,
#  0.9991903305053711,
#  0.9993014335632324,
#  0.9993252754211426,
#  0.9992379546165466,
#  0.9993728995323181,
#  0.999277651309967,
#  0.9994205236434937,
#  0.9993411302566528,
#  0.9994522929191589,
#  0.9995157718658447,
#  0.9995792508125305,
#  0.9993411302566528,
#  0.999634861946106,
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot the accuracy curves
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
main_acc = history.history['accuracy']

main_val_acc = history.history['val_accuracy']


main_loss = history.history['loss']

main_val_loss = history.history['val_loss']


epochs = range(1, len(main_acc) + 1)

plt.plot(epochs, main_acc, 'r', label='Training Accuracy Main Model')


plt.plot(epochs, main_val_acc, 'b', label='Validation Accuracy Main Model')
plt.legend()
plt.grid(False)
plt.savefig('Net_aaccuracy.png', bbox_inches='tight',dpi=600)

plt.figure()

plt.plot(epochs, main_loss, 'r', label='Training Loss Main Model')

plt.plot(epochs, main_val_loss, 'b', label='Validation Loss Main Model')

plt.ylim([-1, 8])
plt.title('Training and validation loss for Both Model')

plt.legend()
plt.grid(False)
plt.savefig('Net_loss.png', bbox_inches='tight',dpi=600)
plt.show()

# %% [markdown]
# # **Confusion Matrix**

# %%
# Convert DataFrame to NumPy array
y_21_test_array = y_21_test.to_numpy()

# Reshape the one-hot encoded labels
Y_test_reshaped = y_21_test_array.reshape(-1, 5)

# Obtain the predicted values
Y_pred = model.predict(x_21_test)

# Convert the one-hot encoded labels to scalar values
Y_test_scalar = np.argmax(Y_test_reshaped, axis=1)
Y_pred_scalar = np.argmax(Y_pred, axis=1)

# Calculate the confusion matrix
cm = confusion_matrix(Y_test_scalar, Y_pred_scalar)

# Print the confusion matrix
print(cm)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["normal","probe","dos","u2r","r2l"])
disp.plot()
plt.savefig('confusion_Net_multiclass.png', bbox_inches='tight',dpi=600)
plt.grid(False)
plt.show()
# Out:
# 371/371 [==============================] - 1s 3ms/step
# [[2152    0    0    0    0]
#  [   0 2402    0    0    0]
#  [   0    0 4342    0    0]
#  [   0    0   67    0    0]
#  [   0    1    2    0 2884]]

# %%
CM = ConfusionMatrix(actual_vector=Y_test_scalar, predict_vector=Y_pred_scalar)
CM.relabel(mapping={0:"normal",1:"probe",2:"dos",3:"u2r",4:"r2l"})

# %%
print(CM)
# Out:
# Predict      normal       probe        dos          u2r          r2l
# Actual
# normal       2152         0            0            0            0
#
# probe        0            2402         0            0            0
#
# dos          0            0            4342         0            0
#
# u2r          0            0            67           0            0
#
# r2l          0            1            2            0            2884
#
#
#
#
#
# Overall Statistics :
#
# 95% CI                                                            (0.99271,0.99547)
# ACC Macro                                                         0.99764
# ARI                                                               0.98876
# AUNP                                                              0.99535
# AUNU                                                              0.89897
# Bangdiwala B                                                      0.9918
# Bennett S                                                         0.99262
# CBA                                                               0.79658
# CSI                                                               None
# Chi-Squared                                                       None
# Chi-Squared DF                                                    16
# Conditional Entropy                                               0.00311
# Cramer V                                                          None
# Cross Entropy                                                     1.93266
# F1 Macro                                                          0.79828
# F1 Micro                                                          0.99409
# FNR Macro                                                         0.20021
# FNR Micro                                                         0.00591
# FPR Macro                                                         0.00186
# FPR Micro                                                         0.00148
# Gwet AC1                                                          0.99277
# Hamming Loss                                                      0.00591
# Joint Entropy                                                     1.98607
# KL Divergence                                                     None
# Kappa                                                             0.99191
# Kappa 95% CI                                                      (0.99002,0.9938)
# Kappa No Prevalence                                               0.98819
# Kappa Standard Error                                              0.00096
# Kappa Unbiased                                                    0.99191
# Krippendorff Alpha                                                0.99191
# Lambda A                                                          0.99068
# Lambda B                                                          0.9996
# Mutual Information                                                1.93753
# NIR                                                               0.36641
# Overall ACC                                                       0.99409
# Overall CEN                                                       0.00764
# Overall J                                                         (3.9829,0.79658)
# Overall MCC                                                       0.99196
# Overall MCEN                                                      0.01316
# Overall RACC                                                      0.26977
# Overall RACCU                                                     0.26979
# P-Value                                                           None
# PPV Macro                                                         None
# PPV Micro                                                         0.99409
# Pearson C                                                         None
# Phi-Squared                                                       None
# RCI                                                               0.97709
# RR                                                                2370.0
# Reference Entropy                                                 1.98296
# Response Entropy                                                  1.94064
# SOA1(Landis & Koch)                                               Almost Perfect
# SOA2(Fleiss)                                                      Excellent
# SOA3(Altman)                                                      Very Good
# SOA4(Cicchetti)                                                   Excellent
# SOA5(Cramer)                                                      None
# SOA6(Matthews)                                                    Very Strong
# SOA7(Lambda A)                                                    Very Strong
# SOA8(Lambda B)                                                    Very Strong
# SOA9(Krippendorff Alpha)                                          High
# SOA10(Pearson C)                                                  None
# Scott PI                                                          0.99191
# Standard Error                                                    0.0007
# TNR Macro                                                         0.99814
# TNR Micro                                                         0.99852
# TPR Macro                                                         0.79979
# TPR Micro                                                         0.99409
# Zero-one Loss                                                     70
#
# Class Statistics :
#
# Classes                                                           normal        probe         dos           u2r           r2l
# ACC(Accuracy)                                                     1.0           0.99992       0.99418       0.99435       0.99975
# AGF(Adjusted F-score)                                             1.0           0.99995       0.99749       0.0           0.99945
# AGM(Adjusted geometric mean)                                      1.0           0.99992       0.99362       0             0.9997
# AM(Difference between automatic and manual classification)        0             1             69            -67           -3
# AUC(Area under the ROC curve)                                     1.0           0.99995       0.9954        0.5           0.99948
# AUCI(AUC value interpretation)                                    Excellent     Excellent     Excellent     Poor          Excellent
# AUPR(Area under the PR curve)                                     1.0           0.99979       0.99218       None          0.99948
# BB(Braun-Blanquet similarity)                                     1.0           0.99958       0.98436       0.0           0.99896
# BCD(Bray-Curtis dissimilarity)                                    0.0           4e-05         0.00291       0.00283       0.00013
# BM(Informedness or bookmaker informedness)                        1.0           0.99989       0.99081       0.0           0.99896
# CEN(Confusion entropy)                                            0             0.00085       0.01886       0.0           0.00205
# DOR(Diagnostic odds ratio)                                        None          None          None          None          None
# DP(Discriminant power)                                            None          None          None          None          None
# DPI(Discriminant power interpretation)                            None          None          None          None          None
# ERR(Error rate)                                                   0.0           8e-05         0.00582       0.00565       0.00025
# F0.5(F0.5 score)                                                  1.0           0.99967       0.98745       0.0           0.99979
# F1(F1 score - harmonic mean of precision and sensitivity)         1.0           0.99979       0.99212       0.0           0.99948
# F2(F2 score)                                                      1.0           0.99992       0.99683       0.0           0.99917
# FDR(False discovery rate)                                         0.0           0.00042       0.01564       None          0.0
# FN(False negative/miss/type 2 error)                              0             0             0             67            3
# FNR(Miss rate or false negative rate)                             0.0           0.0           0.0           1.0           0.00104
# FOR(False omission rate)                                          0.0           0.0           0.0           0.00565       0.00033
# FP(False positive/type 1 error/false alarm)                       0             1             69            0             0
# FPR(Fall-out or false positive rate)                              0.0           0.00011       0.00919       0.0           0.0
# G(G-measure geometric mean of precision and sensitivity)          1.0           0.99979       0.99215       None          0.99948
# GI(Gini index)                                                    1.0           0.99989       0.99081       0.0           0.99896
# GM(G-mean geometric mean of specificity and sensitivity)          1.0           0.99995       0.99539       0.0           0.99948
# HD(Hamming distance)                                              0             1             69            67            3
# IBA(Index of balanced accuracy)                                   1.0           1.0           0.99992       0.0           0.99792
# ICSI(Individual classification success index)                     1.0           0.99958       0.98436       None          0.99896
# IS(Information score)                                             2.46114       2.30198       1.42571       None          2.03724
# J(Jaccard index)                                                  1.0           0.99958       0.98436       0.0           0.99896
# LS(Lift score)                                                    5.50651       4.93134       2.68647       None          4.10461
# MCC(Matthews correlation coefficient)                             1.0           0.99974       0.98758       None          0.99931
# MCCI(Matthews correlation coefficient interpretation)             Very Strong   Very Strong   Very Strong   None          Very Strong
# MCEN(Modified confusion entropy)                                  0             0.00156       0.03226       0.0           0.00375
# MK(Markedness)                                                    1.0           0.99958       0.98436       None          0.99967
# N(Condition negative)                                             9698          9448          7508          11783         8963
# NLR(Negative likelihood ratio)                                    0.0           0.0           0.0           1.0           0.00104
# NLRI(Negative likelihood ratio interpretation)                    Good          Good          Good          Negligible    Good
# NPV(Negative predictive value)                                    1.0           1.0           1.0           0.99435       0.99967
# OC(Overlap coefficient)                                           1.0           1.0           1.0           None          1.0
# OOC(Otsuka-Ochiai coefficient)                                    1.0           0.99979       0.99215       None          0.99948
# OP(Optimized precision)                                           1.0           0.99986       0.98956       -0.00565      0.99923
# P(Condition positive or support)                                  2152          2402          4342          67            2887
# PLR(Positive likelihood ratio)                                    None          9448.0        108.81159     None          None
# PLRI(Positive likelihood ratio interpretation)                    None          Good          Good          None          None
# POP(Population)                                                   11850         11850         11850         11850         11850
# PPV(Precision or positive predictive value)                       1.0           0.99958       0.98436       None          1.0
# PRE(Prevalence)                                                   0.1816        0.2027        0.36641       0.00565       0.24363
# Q(Yule Q - coefficient of colligation)                            None          None          None          None          None
# QI(Yule Q interpretation)                                         None          None          None          None          None
# RACC(Random accuracy)                                             0.03298       0.0411        0.13639       0.0           0.05929
# RACCU(Random accuracy unbiased)                                   0.03298       0.0411        0.1364        1e-05         0.05929
# TN(True negative/correct rejection)                               9698          9447          7439          11783         8963
# TNR(Specificity or true negative rate)                            1.0           0.99989       0.99081       1.0           1.0
# TON(Test outcome negative)                                        9698          9447          7439          11850         8966
# TOP(Test outcome positive)                                        2152          2403          4411          0             2884
# TP(True positive/hit)                                             2152          2402          4342          0             2884
# TPR(Sensitivity, recall, hit rate, or true positive rate)         1.0           1.0           1.0           0.0           0.99896
# Y(Youden index)                                                   1.0           0.99989       0.99081       0.0           0.99896
# dInd(Distance index)                                              0.0           0.00011       0.00919       1.0           0.00104
# sInd(Similarity index)                                            1.0           0.99993       0.9935        0.29289       0.99927

# %%
from sklearn.metrics import classification_report
target_names = ['normal','probe','dos','u2r','r2l']
print(classification_report(Y_test_scalar, Y_pred_scalar, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#       normal       1.00      1.00      1.00      2152
#        probe       1.00      1.00      1.00      2402
#          dos       0.98      1.00      0.99      4342
#          u2r       0.00      0.00      0.00        67
#          r2l       1.00      1.00      1.00      2887
#
#     accuracy                           0.99     11850
#    macro avg       0.80      0.80      0.80     11850
# weighted avg       0.99      0.99      0.99     11850
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
acc_21 = accuracy_score(Y_test_scalar, Y_pred_scalar)* 100
recall = recall_score(Y_test_scalar, Y_pred_scalar , average="weighted")
precision = precision_score(Y_test_scalar, Y_pred_scalar , average="weighted")
f1 = f1_score(Y_test_scalar, Y_pred_scalar, average="weighted")
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print("accuracy")
print("%.3f" %acc_21)
print("racall")
print("%.3f" %recall)
print("precision")
print("%.3f" %precision)
print("f1score")
print(f1)
# Out:
# accuracy
# 99.409
# racall
# 0.994
# precision
# 0.989
# f1score
# 0.9912887163034169

# %%
# data = pd.read_csv('/content/training.log', sep=',', header=None)
# data.to_csv('training.csv', index=False)

# %%
# from google.colab import files
# files.download('training.csv')
